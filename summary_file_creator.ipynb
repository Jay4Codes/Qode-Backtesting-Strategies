# %%
import os
import pandas as pd


all_positions = pd.DataFrame()

OPTIONS_FOLDER = "database/options/"

def load_expiry_folders():
    return os.listdir(OPTIONS_FOLDER)

# %%
import pandas as pd

def get_nearest_expiry(expiry_folders, timestamp):
    nearest_expiry_folder = None
    for expiry_folder in expiry_folders:
        expiry_date = pd.to_datetime(expiry_folder)
        if expiry_date >= timestamp:
            if nearest_expiry_folder is None or expiry_date < nearest_expiry_folder:
                nearest_expiry_folder = expiry_date

    nearest_expiry_folder = (
        pd.to_datetime(nearest_expiry_folder).strftime("%d%b%y").upper()
    )

    return nearest_expiry_folder

# %%
from summary import calculate_stats_from_trades, generate_markdown_report

expiry_folders = load_expiry_folders()
positions_files = []


for root, dirs, files in os.walk("directional_results"):
    for file in files:
        if file.endswith("positions.csv"):
            positions_files.append(os.path.join(root, file))


non_empty_positions_files = [
    file for file in positions_files if os.path.getsize(file) > 2
]


if non_empty_positions_files:
    positions = pd.DataFrame()
    for file in non_empty_positions_files:
        print(f"Processing {file}...")
        positions_df = pd.read_csv(file)
        new_positions_df = pd.DataFrame()

        print(f"Found {len(positions_df)} positions...")

        for i in range(0, len(positions_df), 2):
            if i + 1 >= len(positions_df):
                continue

            row1 = positions_df.iloc[i]
            row2 = positions_df.iloc[i + 1]

            new_row = {}

            new_row["Instruments"] = (
                str(row1["Strike"])
                + str(row1["Option Type"])
                + ", "
                + str(row2["Strike"])
                + str(row2["Option Type"])
            )

            new_row["Entry Timestamp"] = min(
                row1["Entry Timestamp"], row2["Entry Timestamp"]
            )

            new_row["Entry Price"] = row1["Entry Price"] + row2["Entry Price"]

            new_row["Exit Timestamp"] = max(
                row1["Exit Timestamp"], row2["Exit Timestamp"]
            )

            new_row["Exit Price"] = row1["Exit Price"] + row2["Exit Price"]

            new_row["Quantity"] = row1["Quantity"] + row2["Quantity"]

            new_row["Lot Size"] = row1["Lot Size"]

            new_row["PnL per Lot"] = row1["PnL per Lot"] + row2["PnL per Lot"]

            new_row["Cost per Lot"] = row1["Cost per Lot"] + row2["Cost per Lot"]

            new_row["Net PnL per Lot"] = (
                row1["Net PnL per Lot"] + row2["Net PnL per Lot"]
            )

            new_row["Exit Reason"] = row1["Exit Reason"]

            new_row["Nearest Expiry Date"] = get_nearest_expiry(
                expiry_folders, pd.to_datetime(new_row["Exit Timestamp"].split(" ")[0])
            )

            new_row["Days to Expiry"] = (
                pd.to_datetime(new_row["Nearest Expiry Date"])
                - pd.to_datetime(new_row["Exit Timestamp"])
            ).days + 1

            new_row["Expiry Day Flag"] = new_row["Days to Expiry"] == 0

            new_row["Month"] = pd.to_datetime(new_row["Exit Timestamp"]).month

            new_row["Hold Time"] = max(row1["Hold Time"], row2["Hold Time"])

            new_positions_df = pd.concat([new_positions_df, pd.DataFrame([new_row])])

        print(f"Created {len(new_positions_df)} positions...")

        positions = pd.concat([positions, new_positions_df])

    print(f"Final positions count: {len(positions)}")

    positions = positions.sort_values(by="Entry Timestamp")


positions.to_csv("directional_results_combined_positions.csv", index=False)

positions["Entry Timestamp"] = positions["Entry Timestamp"].apply(
    lambda x: pd.to_datetime(x)
)
positions["Exit Timestamp"] = positions["Exit Timestamp"].apply(
    lambda x: pd.to_datetime(x)
)
positions["Expiry Day Flag"] = positions["Expiry Day Flag"].astype(bool)

stats = calculate_stats_from_trades(trades=positions)
stats = pd.DataFrame(stats, index=[0])
cols = stats.columns.tolist()

stats.to_csv("directional_results_combined_stats.csv", index=False)

generate_markdown_report(
    trades=positions,
    template_path="report_template.md",
    output_path="directional_results_combined_report.md",
)
# Out:
# Processing directional_results\2024-01-01_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-01-02_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-01-03_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-01-04_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-01-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-01-08_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-01-09_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-01-10_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-01-12_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-01-15_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-01-16_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-01-17_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-01-18_positions.csv...
# Found 20 positions...
# Created 10 positions...
# Processing directional_results\2024-01-19_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-01-20_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-01-23_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-01-24_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-01-25_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-01-29_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-01-30_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-01-31_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-01_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-02-02_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-05_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-06_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-07_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-08_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-02-09_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-12_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-02-13_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-14_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-15_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-02-16_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-19_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-02-20_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-02-21_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-02-22_positions.csv...
# Found 28 positions...
# Created 14 positions...
# Processing directional_results\2024-02-23_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-02-26_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-02-27_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-02-28_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-02-29_positions.csv...
# Found 20 positions...
# Created 10 positions...
# Processing directional_results\2024-03-01_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-03-04_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-03-05_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-03-06_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-03-07_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-03-11_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-03-12_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-03-13_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-03-14_positions.csv...
# Found 18 positions...
# Created 9 positions...
# Processing directional_results\2024-03-15_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-03-18_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-03-19_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-03-20_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-03-21_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-03-22_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-03-26_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-03-27_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-03-28_positions.csv...
# Found 24 positions...
# Created 12 positions...
# Processing directional_results\2024-04-01_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-04-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-04-03_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-04-04_positions.csv...
# Found 22 positions...
# Created 11 positions...
# Processing directional_results\2024-04-05_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-04-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-04-09_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-04-10_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-04-12_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-04-15_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-04-16_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-04-18_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-04-19_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-04-22_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-04-23_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-04-24_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-04-25_positions.csv...
# Found 20 positions...
# Created 10 positions...
# Processing directional_results\2024-04-26_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-04-29_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-04-30_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-05-02_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-05-03_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-05-06_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-05-07_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-05-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-05-09_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-05-10_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-05-13_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-05-14_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-05-15_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-05-16_positions.csv...
# Found 30 positions...
# Created 15 positions...
# Processing directional_results\2024-05-17_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-05-21_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-05-22_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-05-23_positions.csv...
# Found 28 positions...
# Created 14 positions...
# Processing directional_results\2024-05-24_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-05-27_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-05-28_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-05-29_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-05-30_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing directional_results\2024-05-31_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-06-04_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-06-05_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-06-06_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-06-07_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-06-10_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-06-11_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-06-12_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-06-13_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-06-14_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-06-18_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing directional_results\2024-06-19_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-06-20_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-06-21_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-06-24_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-06-25_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-06-26_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-06-27_positions.csv...
# Found 18 positions...
# Created 9 positions...
# Processing directional_results\2024-06-28_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-01_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-02_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-03_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-07-04_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-07-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-08_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-09_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-07-10_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-07-11_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-07-12_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-07-15_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-16_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-07-18_positions.csv...
# Found 34 positions...
# Created 17 positions...
# Processing directional_results\2024-07-19_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-22_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-07-23_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-24_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-07-25_positions.csv...
# Found 22 positions...
# Created 11 positions...
# Processing directional_results\2024-07-26_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-07-29_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-07-30_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-07-31_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-08-02_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-08-05_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-06_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-07_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-08-08_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-08-09_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-08-12_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-13_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-08-14_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-08-16_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-19_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-20_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-08-21_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-23_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-08-26_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-27_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-08-28_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-08-29_positions.csv...
# Found 24 positions...
# Created 12 positions...
# Processing directional_results\2024-08-30_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-09-02_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-09-03_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-09-04_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-09-05_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-09-06_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-09-09_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-09-10_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-09-11_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-09-12_positions.csv...
# Found 34 positions...
# Created 17 positions...
# Processing directional_results\2024-09-13_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-09-16_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-09-17_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-09-18_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-09-19_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-09-20_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-09-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-09-24_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-09-25_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-09-26_positions.csv...
# Found 22 positions...
# Created 11 positions...
# Processing directional_results\2024-09-27_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-09-30_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-10-01_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-10-03_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-10-04_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-10-07_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-10-08_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-10-09_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-10-10_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-10-11_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-10-14_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-10-15_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-10-16_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-10-18_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-10-21_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-10-22_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-10-23_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-10-24_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-10-25_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-10-28_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-10-29_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-10-30_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-11-04_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-11-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-11-06_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-11-07_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-11-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-11-11_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-11-12_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-11-13_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-11-14_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-11-18_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-11-19_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing directional_results\2024-11-21_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing directional_results\2024-11-22_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-11-25_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-11-26_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-11-27_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-11-28_positions.csv...
# Found 22 positions...
# Created 11 positions...
# Processing directional_results\2024-11-29_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-12-02_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-12-03_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-12-04_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-12-05_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-12-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing directional_results\2024-12-09_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-12-10_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-12-11_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-12-12_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-12-13_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-12-16_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-12-17_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing directional_results\2024-12-18_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing directional_results\2024-12-19_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-12-20_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing directional_results\2024-12-23_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-12-24_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing directional_results\2024-12-26_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-12-27_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing directional_results\2024-12-30_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing directional_results\2024-12-31_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Final positions count: 1181
# Markdown report saved to directional_results_combined_report.md
# {'Trade Month': 'Unknown',
#  'Max Capital Required': 72087.449625,
#  'Return On Capital': np.float64(-87.89776237499997),
#  'Total Cost': np.float64(39339.47475000001),
#  'PnL': np.float64(-136456.04999999996),
#  'Net PnL': np.float64(-175795.52474999995),
#  'Win Rate': 0.3022861981371719,
#  'Profit Factor': np.float64(0.7071531879992385),
#  'Expiry Day PnL': np.float64(-59101.899825),
#  'Average Return per Trade': np.float64(-148.85311155800164),
#  'Total Trades': 1181,
#  'Profitable Trades': 337,
#  'Losing Trades': 844,
#  'Average Duration': np.float64(39.53175275190517),
#  'Average Winning Trade': np.float64(1259.6529763353117),
#  'Average Losing Trade': np.float64(-711.2542390699051),
#  'Largest Winning Trade': np.float64(12688.064400000003),
#  'Largest Losing Trade': np.float64(-5843.877675),
#  'Risk Reward Ratio': np.float64(1.7710305361167873),
#  'CAGR': np.float64(-0.8789776237500009),
#  'Calmar Ratio': np.float64(-0.9783264444959435),
#  'Consecutive Wins': np.int64(5),
#  'Consecutive Losses': np.int64(20),
#  'Max Drawdown': 0.898450234781163,
#  'Percent Profitable Days': 0.29583333333333334,
#  'Best Day PnL': np.float64(9421.959225000002),
#  'Worst Day PnL': np.float64(-21747.037199999995),
#  'Expiry Day Net Pnl': np.float64(-59101.899825),
#  'Expiry Day Win Ratio': 0.2118380062305296,
#  'TotalNumberOfExpiryTrades': 321,
#  '9:20 to 14:45 Net PnL': np.float64(-143825.19179999994),
#  '9:20 to 14:45 Win Ratio': 0.29053420805998126,
#  '9:20 to 14:45 Trades': 1067,
#  '14:45 to 15:30 Net PnL': np.float64(-31970.33295),
#  '14:45 to 15:30 Win Ratio': 0.23684210526315788,
#  '14:45 to 15:30 Trades': 114,
#  'timestamp': '2025-03-26 16:49:41',
#  'Total Capital Deployment': 200000,
#  'PnL_Jan-2024': -8542.751699999984,
#  'PnL_Feb-2024': -16834.460325,
#  'PnL_Mar-2024': -15093.778350000008,
#  'PnL_Apr-2024': -5707.376175000005,
#  'PnL_May-2024': -14128.549124999974,
#  'PnL_Jun-2024': -29949.79259999999,
#  'PnL_Jul-2024': -18546.97845000001,
#  'PnL_Aug-2024': -9939.445350000009,
#  'PnL_Sep-2024': -20583.358125,
#  'PnL_Oct-2024': -21884.031074999995,
#  'PnL_Nov-2024': -9744.222449999987,
#  'PnL_Dec-2024': -4840.78102499999}

# %%
all_positions = pd.concat([all_positions, positions])

# %%
import plotly.graph_objects as go

equity_curve = positions[["Exit Timestamp", "Net PnL per Lot"]].copy()
equity_curve["Cumulative PnL"] = equity_curve["Net PnL per Lot"].cumsum() + 200000

fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=equity_curve["Exit Timestamp"],
        y=equity_curve["Cumulative PnL"],
        mode="lines",
        name="Equity Curve",
    )
)

fig.update_layout(
    title="Equity Curve",
    xaxis_title="Date",
    yaxis_title="Cumulative PnL",
    showlegend=True,
)

fig.write_html("directional_results_combined_equity_curve.html")

# %%
from summary import calculate_stats_from_trades, generate_markdown_report

expiry_folders = load_expiry_folders()

positions_files = []

for root, dirs, files in os.walk("semi_directional_results"):

    for file in files:

        if file.endswith("positions.csv"):

            positions_files.append(os.path.join(root, file))


non_empty_positions_files = [
    file for file in positions_files if os.path.getsize(file) > 2
]


if non_empty_positions_files:

    positions = pd.DataFrame()

    for file in non_empty_positions_files:

        print(f"Processing {file}...")

        positions_df = pd.read_csv(file)

        new_positions_df = pd.DataFrame()

        print(f"Found {len(positions_df)} positions...")

        for i in range(0, len(positions_df), 2):

            if i + 1 >= len(positions_df):

                continue

            row1 = positions_df.iloc[i]

            row2 = positions_df.iloc[i + 1]

            new_row = {}

            new_row["Instruments"] = (
                str(row1["Strike"])
                + str(row1["Option Type"])
                + ", "
                + str(row2["Strike"])
                + str(row2["Option Type"])
            )

            new_row["Entry Timestamp"] = min(
                row1["Entry Timestamp"], row2["Entry Timestamp"]
            )

            new_row["Entry Price"] = row1["Entry Price"] + row2["Entry Price"]

            new_row["Exit Timestamp"] = max(
                row1["Exit Timestamp"], row2["Exit Timestamp"]
            )

            new_row["Exit Price"] = row1["Exit Price"] + row2["Exit Price"]

            new_row["Quantity"] = row1["Quantity"] + row2["Quantity"]

            new_row["Lot Size"] = row1["Lot Size"]

            new_row["PnL per Lot"] = row1["PnL per Lot"] + row2["PnL per Lot"]

            new_row["Cost per Lot"] = row1["Cost per Lot"] + row2["Cost per Lot"]

            new_row["Net PnL per Lot"] = (
                row1["Net PnL per Lot"] + row2["Net PnL per Lot"]
            )

            new_row["Exit Reason"] = row1["Exit Reason"]

            new_row["Nearest Expiry Date"] = get_nearest_expiry(
                expiry_folders, pd.to_datetime(new_row["Exit Timestamp"].split(" ")[0])
            )

            new_row["Days to Expiry"] = (
                pd.to_datetime(new_row["Nearest Expiry Date"])
                - pd.to_datetime(new_row["Exit Timestamp"])
            ).days + 1

            new_row["Expiry Day Flag"] = new_row["Days to Expiry"] == 0
            
            new_row["Month"] = pd.to_datetime(new_row["Exit Timestamp"]).month

            new_row["Hold Time"] = max(row1["Hold Time"], row2["Hold Time"])

            new_positions_df = pd.concat([new_positions_df, pd.DataFrame([new_row])])

        print(f"Created {len(new_positions_df)} positions...")

        positions = pd.concat([positions, new_positions_df])

    print(f"Final positions count: {len(positions)}")

    positions = positions.sort_values(by="Entry Timestamp")


positions.to_csv("semi_directional_results_combined_positions.csv", index=False)

positions["Entry Timestamp"] = positions["Entry Timestamp"].apply(
    lambda x: pd.to_datetime(x)
)
positions["Exit Timestamp"] = positions["Exit Timestamp"].apply(
    lambda x: pd.to_datetime(x)
)
positions["Expiry Day Flag"] = positions["Expiry Day Flag"].astype(bool)

stats = calculate_stats_from_trades(trades=positions)
stats = pd.DataFrame(stats, index=[0])
cols = stats.columns.tolist()

stats.to_csv("semi_directional_results_combined_stats.csv", index=False)

generate_markdown_report(
    trades=positions,
    template_path="report_template.md",
    output_path="semi_directional_results_combined_report.md"
)
# Out:
# Processing semi_directional_results\2024-01-01_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-01-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-01-03_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-01-04_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-01-05_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-01-08_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-01-09_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-01-10_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing semi_directional_results\2024-01-12_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-01-15_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-01-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-01-18_positions.csv...
# Found 24 positions...
# Created 12 positions...
# Processing semi_directional_results\2024-01-19_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-01-23_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-01-24_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing semi_directional_results\2024-01-25_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-01-29_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-01-30_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-01-31_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-02-01_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-02-02_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-02-05_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-02-06_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-02-09_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-02-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-02-13_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-02-14_positions.csv...
# Found 18 positions...
# Created 9 positions...
# Processing semi_directional_results\2024-02-15_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-02-16_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-02-19_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-02-20_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-02-21_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-02-22_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-02-23_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-02-26_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-02-27_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-02-28_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-02-29_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-03-01_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-03-04_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-03-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-03-06_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing semi_directional_results\2024-03-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-03-14_positions.csv...
# Found 26 positions...
# Created 13 positions...
# Processing semi_directional_results\2024-03-15_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-03-18_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-03-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-03-20_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-03-21_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-03-22_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-03-26_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-03-27_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-03-28_positions.csv...
# Found 36 positions...
# Created 18 positions...
# Processing semi_directional_results\2024-04-01_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-04-02_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-04-03_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-04-04_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing semi_directional_results\2024-04-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-04-08_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-04-09_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-04-10_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-04-12_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-04-15_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-04-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-04-18_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing semi_directional_results\2024-04-19_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-04-22_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-04-23_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-04-24_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-04-25_positions.csv...
# Found 30 positions...
# Created 15 positions...
# Processing semi_directional_results\2024-04-26_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-04-29_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-04-30_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-05-02_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-05-03_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-05-06_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-05-07_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-05-08_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-05-10_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-05-13_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-05-14_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-05-15_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-05-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-05-17_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-05-21_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-05-22_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-05-23_positions.csv...
# Found 30 positions...
# Created 15 positions...
# Processing semi_directional_results\2024-05-24_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-05-27_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-05-28_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-05-29_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-05-31_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-06-04_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-06-05_positions.csv...
# Found 16 positions...
# Created 8 positions...
# Processing semi_directional_results\2024-06-06_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-06-07_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-06-11_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-06-12_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-06-14_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-06-18_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-06-19_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-06-20_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-06-21_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-06-24_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-06-25_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-06-26_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-06-27_positions.csv...
# Found 18 positions...
# Created 9 positions...
# Processing semi_directional_results\2024-06-28_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-07-01_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-07-02_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-07-03_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-07-04_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-07-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-07-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-07-09_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-07-10_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-07-12_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing semi_directional_results\2024-07-15_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-07-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-07-18_positions.csv...
# Found 32 positions...
# Created 16 positions...
# Processing semi_directional_results\2024-07-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-07-22_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-07-23_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-07-24_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-07-25_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-07-26_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-07-29_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-07-30_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-07-31_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-08-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-08-05_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-08-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-08-07_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-08-08_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-08-09_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-08-12_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-08-13_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-08-16_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-08-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-08-20_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-08-21_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-08-23_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-08-26_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-08-27_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-08-28_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-08-29_positions.csv...
# Found 24 positions...
# Created 12 positions...
# Processing semi_directional_results\2024-08-30_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-09-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-09-03_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-09-04_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-09-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-09-09_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-09-10_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-09-11_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-09-12_positions.csv...
# Found 28 positions...
# Created 14 positions...
# Processing semi_directional_results\2024-09-13_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-09-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-09-17_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-09-18_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-09-19_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-09-20_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-09-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-09-24_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-09-25_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-09-26_positions.csv...
# Found 38 positions...
# Created 19 positions...
# Processing semi_directional_results\2024-09-27_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-10-01_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-10-03_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-10-04_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-10-07_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-10-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-10-09_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-10-10_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-10-11_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-10-14_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-10-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-10-18_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-10-21_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-10-22_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-10-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-10-25_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-10-28_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-10-29_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-10-30_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-11-04_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-11-05_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-11-06_positions.csv...
# Found 12 positions...
# Created 6 positions...
# Processing semi_directional_results\2024-11-08_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-11-11_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-11-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-11-14_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-11-18_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-11-19_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-11-22_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-11-25_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-11-26_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-11-27_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-11-28_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-11-29_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-12-02_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-12-03_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-12-04_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-12-05_positions.csv...
# Found 40 positions...
# Created 20 positions...
# Processing semi_directional_results\2024-12-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-12-09_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-12-10_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-12-11_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-12-12_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-12-13_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing semi_directional_results\2024-12-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-12-18_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-12-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-12-20_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing semi_directional_results\2024-12-23_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-12-24_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing semi_directional_results\2024-12-27_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing semi_directional_results\2024-12-30_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing semi_directional_results\2024-12-31_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Final positions count: 780
# Markdown report saved to semi_directional_results_combined_report.md
# {'Trade Month': 'Unknown',
#  'Max Capital Required': 63996.349725,
#  'Return On Capital': np.float64(-15.235692187499989),
#  'Total Cost': np.float64(21608.634375),
#  'PnL': np.float64(-8862.749999999982),
#  'Net PnL': np.float64(-30471.38437499998),
#  'Win Rate': 0.3128205128205128,
#  'Profit Factor': np.float64(0.9244315323805846),
#  'Expiry Day PnL': np.float64(-5767.764074999996),
#  'Average Return per Trade': np.float64(-39.06587740384613),
#  'Total Trades': 780,
#  'Profitable Trades': 241,
#  'Losing Trades': 539,
#  'Average Duration': np.float64(51.991025641025644),
#  'Average Winning Trade': np.float64(1546.7113702282159),
#  'Average Losing Trade': np.float64(-748.105425974026),
#  'Largest Winning Trade': np.float64(11866.040550000005),
#  'Largest Losing Trade': np.float64(-2511.8700000000017),
#  'Risk Reward Ratio': np.float64(2.067504547523382),
#  'CAGR': np.float64(-0.15235692187499983),
#  'Calmar Ratio': np.float64(-0.6859702041130208),
#  'Consecutive Wins': np.int64(6),
#  'Consecutive Losses': np.int64(17),
#  'Max Drawdown': 0.2221042852320411,
#  'Percent Profitable Days': 0.37155963302752293,
#  'Best Day PnL': np.float64(12120.128775000008),
#  'Worst Day PnL': np.float64(-3896.7845250000005),
#  'Expiry Day Net Pnl': np.float64(-5767.764074999996),
#  'Expiry Day Win Ratio': 0.275,
#  'TotalNumberOfExpiryTrades': 240,
#  '9:20 to 14:45 Net PnL': np.float64(-16589.727224999973),
#  '9:20 to 14:45 Win Ratio': 0.31029810298102983,
#  '9:20 to 14:45 Trades': 738,
#  '14:45 to 15:30 Net PnL': np.float64(-13881.657150000005),
#  '14:45 to 15:30 Win Ratio': 0.2857142857142857,
#  '14:45 to 15:30 Trades': 42,
#  'timestamp': '2025-03-26 16:50:04',
#  'Total Capital Deployment': 200000,
#  'PnL_Jan-2024': 1381.1421749999913,
#  'PnL_Feb-2024': -7846.313774999997,
#  'PnL_Mar-2024': -13487.295075000005,
#  'PnL_Apr-2024': -7610.610074999996,
#  'PnL_May-2024': -4476.908325000015,
#  'PnL_Jun-2024': 8045.066625000012,
#  'PnL_Jul-2024': -4191.550499999997,
#  'PnL_Aug-2024': 13630.29592500001,
#  'PnL_Sep-2024': -13060.224150000004,
#  'PnL_Oct-2024': 2128.8249750000095,
#  'PnL_Nov-2024': -4027.180574999997,
#  'PnL_Dec-2024': -956.6315999999961}

# %%
import plotly.graph_objects as go

equity_curve = positions[["Exit Timestamp", "Net PnL per Lot"]].copy()
equity_curve["Cumulative PnL"] = equity_curve["Net PnL per Lot"].cumsum() + 200000

fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=equity_curve["Exit Timestamp"],
        y=equity_curve["Cumulative PnL"],
        mode="lines",
        name="Equity Curve",
    )
)

fig.update_layout(
    title="Equity Curve",
    xaxis_title="Date",
    yaxis_title="Cumulative PnL",
    showlegend=True,
)

fig.write_html("semi_directional_results_combined_equity_curve.html")

# %%
all_positions = pd.concat([all_positions, positions])

# %%
from summary import calculate_stats_from_trades, generate_markdown_report

expiry_folders = load_expiry_folders()

positions_files = []

for root, dirs, files in os.walk("mean_reversion_results"):

    for file in files:

        if file.endswith("positions.csv"):

            positions_files.append(os.path.join(root, file))


non_empty_positions_files = [
    file for file in positions_files if os.path.getsize(file) > 2
]


if non_empty_positions_files:

    positions = pd.DataFrame()

    for file in non_empty_positions_files:

        print(f"Processing {file}...")

        positions_df = pd.read_csv(file)

        new_positions_df = pd.DataFrame()

        print(f"Found {len(positions_df)} positions...")

        for i in range(0, len(positions_df), 2):

            if i + 1 >= len(positions_df):

                continue

            row1 = positions_df.iloc[i]

            row2 = positions_df.iloc[i + 1]

            new_row = {}

            new_row["Instruments"] = (
                str(row1["Strike"])
                + str(row1["Option Type"])
                + ", "
                + str(row2["Strike"])
                + str(row2["Option Type"])
            )

            new_row["Entry Timestamp"] = min(
                row1["Entry Timestamp"], row2["Entry Timestamp"]
            )

            new_row["Entry Price"] = row1["Entry Price"] + row2["Entry Price"]

            new_row["Exit Timestamp"] = max(
                row1["Exit Timestamp"], row2["Exit Timestamp"]
            )

            new_row["Exit Price"] = row1["Exit Price"] + row2["Exit Price"]

            new_row["Quantity"] = row1["Quantity"] + row2["Quantity"]

            new_row["Lot Size"] = row1["Lot Size"]

            new_row["PnL per Lot"] = row1["PnL per Lot"] + row2["PnL per Lot"]

            new_row["Cost per Lot"] = row1["Cost per Lot"] + row2["Cost per Lot"]

            new_row["Net PnL per Lot"] = (
                row1["Net PnL per Lot"] + row2["Net PnL per Lot"]
            )

            new_row["Exit Reason"] = row1["Exit Reason"]

            new_row["Nearest Expiry Date"] = get_nearest_expiry(
                expiry_folders, pd.to_datetime(new_row["Exit Timestamp"].split(" ")[0])
            )

            new_row["Days to Expiry"] = (
                pd.to_datetime(new_row["Nearest Expiry Date"])
                - pd.to_datetime(new_row["Exit Timestamp"])
            ).days + 1

            new_row["Expiry Day Flag"] = new_row["Days to Expiry"] == 0

            new_row["Month"] = pd.to_datetime(new_row["Exit Timestamp"]).month

            new_row["Hold Time"] = max(row1["Hold Time"], row2["Hold Time"])

            new_positions_df = pd.concat([new_positions_df, pd.DataFrame([new_row])])

        print(f"Created {len(new_positions_df)} positions...")

        positions = pd.concat([positions, new_positions_df])

    print(f"Final positions count: {len(positions)}")

    positions = positions.sort_values(by="Entry Timestamp")


positions.to_csv("mean_reversion_results_combined_positions.csv", index=False)

positions["Entry Timestamp"] = positions["Entry Timestamp"].apply(
    lambda x: pd.to_datetime(x)
)
positions["Exit Timestamp"] = positions["Exit Timestamp"].apply(
    lambda x: pd.to_datetime(x)
)
positions["Expiry Day Flag"] = positions["Expiry Day Flag"].astype(bool)

stats = calculate_stats_from_trades(trades=positions)
stats = pd.DataFrame(stats, index=[0])
cols = stats.columns.tolist()

stats.to_csv("mean_reversion_results_combined_stats.csv", index=False)

generate_markdown_report(
    trades=positions,
    template_path="report_template.md",
    output_path="mean_reversion_results_combined_report.md",
)
# Out:
# Processing mean_reversion_results\2024-01-01_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-03_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-04_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-01-05_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-01-09_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-10_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-01-12_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-01-15_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-16_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-01-18_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-19_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-01-24_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-01-25_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-29_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-01-30_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-01-31_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-02-01_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-02-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-02-05_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-02-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-02-07_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-02-09_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-02-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-02-13_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-02-14_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-02-15_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-02-16_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-02-19_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-02-20_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-02-21_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-02-22_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-02-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-02-26_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-02-27_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-02-29_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-03-01_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-03-04_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-03-05_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-03-06_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-03-07_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-03-11_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-03-12_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-03-14_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-03-15_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-03-18_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-03-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-03-20_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-03-21_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-03-22_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-03-26_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-03-27_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-03-28_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-04-01_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-04-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-04-03_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-04-04_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-04-05_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-04-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-04-10_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-04-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-04-15_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-04-16_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-04-18_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-04-19_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-04-22_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-04-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-04-24_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-04-25_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-04-26_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-04-29_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-04-30_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-05-02_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-05-03_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-05-06_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-05-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-05-10_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-05-13_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-05-14_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-05-15_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-05-16_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-05-17_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-05-21_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-05-22_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-05-23_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-05-24_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-05-27_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-05-28_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-05-29_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-05-31_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-06-04_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-06-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-06-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-06-07_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-06-10_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-06-11_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-06-12_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-06-13_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-06-14_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-06-19_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-06-20_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-06-21_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-06-24_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-06-25_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-06-26_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-06-27_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-06-28_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-07-01_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-07-02_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-03_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-04_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-05_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-07-08_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-09_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-07-10_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-07-11_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-12_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-07-15_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-07-16_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-18_positions.csv...
# Found 14 positions...
# Created 7 positions...
# Processing mean_reversion_results\2024-07-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-22_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-07-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-07-24_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-25_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-26_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-07-29_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-07-30_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-07-31_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-08-01_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-08-02_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-08-05_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-08-07_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-08-08_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-08-09_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-08-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-08-14_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-08-16_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-08-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-08-20_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-08-21_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-08-22_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-08-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-08-26_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-08-27_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-08-28_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-08-29_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-08-30_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-09-03_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-09-04_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-09-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-09-09_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-09-10_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-09-11_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-09-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-09-13_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-09-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-09-17_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-09-18_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-09-20_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-09-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-09-25_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-09-26_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-09-27_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-09-30_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-10-01_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-10-03_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-10-04_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-10-07_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-10-08_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-10-09_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-10-10_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-10-11_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-10-14_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-10-15_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-10-16_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-10-17_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-10-18_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-10-21_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-10-22_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-10-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-10-25_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-10-28_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-10-29_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-10-30_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-04_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-05_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-06_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-07_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-11-08_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-11_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-13_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-14_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-11-18_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-19_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-22_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-11-25_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-11-26_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-27_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-28_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-11-29_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-12-02_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-12-03_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-12-04_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-12-05_positions.csv...
# Found 10 positions...
# Created 5 positions...
# Processing mean_reversion_results\2024-12-06_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-12-09_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-12-10_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-12-11_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-12-12_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-12-13_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Processing mean_reversion_results\2024-12-16_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-12-18_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-12-19_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-12-20_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-12-23_positions.csv...
# Found 4 positions...
# Created 2 positions...
# Processing mean_reversion_results\2024-12-24_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-12-26_positions.csv...
# Found 2 positions...
# Created 1 positions...
# Processing mean_reversion_results\2024-12-27_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-12-30_positions.csv...
# Found 6 positions...
# Created 3 positions...
# Processing mean_reversion_results\2024-12-31_positions.csv...
# Found 8 positions...
# Created 4 positions...
# Final positions count: 504
# Markdown report saved to mean_reversion_results_combined_report.md
# {'Trade Month': 'Unknown',
#  'Max Capital Required': 66117.79665,
#  'Return On Capital': np.float64(0.7816642500000035),
#  'Total Cost': np.float64(16802.259),
#  'PnL': np.float64(18365.587500000005),
#  'Net PnL': np.float64(1563.328500000007),
#  'Win Rate': 0.6507936507936508,
#  'Profit Factor': np.float64(1.0082739517532957),
#  'Expiry Day PnL': np.float64(2201.5298250000055),
#  'Average Return per Trade': np.float64(3.1018422619047756),
#  'Total Trades': 504,
#  'Profitable Trades': 317,
#  'Losing Trades': 187,
#  'Average Duration': np.float64(34.04563492063492),
#  'Average Winning Trade': np.float64(600.9751942429023),
#  'Average Losing Trade': np.float64(-1010.4053907754011),
#  'Largest Winning Trade': np.float64(5437.637999999997),
#  'Largest Losing Trade': np.float64(-11896.893525),
#  'Risk Reward Ratio': np.float64(0.5947862112866444),
#  'CAGR': np.float64(0.007816642499999915),
#  'Calmar Ratio': np.float64(0.06825073768246581),
#  'Consecutive Wins': np.int64(10),
#  'Consecutive Losses': np.int64(6),
#  'Max Drawdown': 0.11452832255625679,
#  'Percent Profitable Days': 0.6126126126126126,
#  'Best Day PnL': np.float64(6187.025174999998),
#  'Worst Day PnL': np.float64(-14183.422424999999),
#  'Expiry Day Net Pnl': np.float64(2201.5298250000055),
#  'Expiry Day Win Ratio': 0.6132075471698113,
#  'TotalNumberOfExpiryTrades': 106,
#  '9:20 to 14:45 Net PnL': np.float64(-5273.336249999997),
#  '9:20 to 14:45 Win Ratio': 0.6326963906581741,
#  '9:20 to 14:45 Trades': 471,
#  '14:45 to 15:30 Net PnL': np.float64(6836.664750000006),
#  '14:45 to 15:30 Win Ratio': 0.5757575757575758,
#  '14:45 to 15:30 Trades': 33,
#  'timestamp': '2025-03-26 16:50:19',
#  'Total Capital Deployment': 200000,
#  'PnL_Jan-2024': 1839.4675500000046,
#  'PnL_Feb-2024': 1344.660974999987,
#  'PnL_Mar-2024': -3629.3037000000077,
#  'PnL_Apr-2024': -12816.286424999991,
#  'PnL_May-2024': 5037.503775000015,
#  'PnL_Jun-2024': -8590.322699999988,
#  'PnL_Jul-2024': 6751.445999999996,
#  'PnL_Aug-2024': -7551.472049999997,
#  'PnL_Sep-2024': 3510.4065,
#  'PnL_Oct-2024': 2315.003325000005,
#  'PnL_Nov-2024': 4805.011874999995,
#  'PnL_Dec-2024': 8547.21337499999}

# %%
all_positions = pd.concat([all_positions, positions])
all_positions = all_positions.sort_values(by="Entry Timestamp")
all_positions.to_csv("portfolio_combined_positions.csv", index=False)

# %%
import plotly.graph_objects as go

equity_curve = positions[["Exit Timestamp", "Net PnL per Lot"]].copy()
equity_curve["Cumulative PnL"] = equity_curve["Net PnL per Lot"].cumsum() + 200000

fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=equity_curve["Exit Timestamp"],
        y=equity_curve["Cumulative PnL"],
        mode="lines",
        name="Equity Curve",
    )
)

fig.update_layout(
    title="Equity Curve",
    xaxis_title="Date",
    yaxis_title="Cumulative PnL",
    showlegend=True,
)

fig.write_html("mean_reversion_results_combined_equity_curve.html")

# %%
stats = calculate_stats_from_trades(trades=all_positions, starting_capital=400000)
stats = pd.DataFrame(stats, index=[0])
cols = stats.columns.tolist()

stats.to_csv("portfolio_results_combined_stats.csv", index=False)

generate_markdown_report(
    trades=all_positions,
    template_path="report_template.md",
    output_path="portfolio_results_combined_report.md",
    starting_capital=400000,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 stats = calculate_stats_from_trades(trades=all_positions, starting_capital=400000)
#       2 stats = pd.DataFrame(stats, index=[0])
#       3 cols = stats.columns.tolist()
#
# TypeError: calculate_stats_from_trades() got an unexpected keyword argument 'starting_capital'

# %%
import plotly.graph_objects as go

equity_curve = all_positions[["Exit Timestamp", "Net PnL per Lot"]].copy()
equity_curve["Cumulative PnL"] = equity_curve["Net PnL per Lot"].cumsum() + 400000

fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=equity_curve["Exit Timestamp"],
        y=equity_curve["Cumulative PnL"],
        mode="lines",
        name="Equity Curve",
    )
)

fig.update_layout(
    title="Equity Curve",
    xaxis_title="Date",
    yaxis_title="Cumulative PnL",
    showlegend=True,
)

fig.write_html("portfolio_results_combined_equity_curve.html")
